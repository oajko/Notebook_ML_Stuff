# %%
import hourglass
import losses
import utils
import datagen
import json

# %%
with open('Aquarium/train/_annotations.coco.json', mode = 'r', encoding = 'utf-8') as file:
    json_data = json.load(file)

# %%
utils.display_im(r'Aquarium\train\IMG_2274_jpeg_jpg.rf.2f319e949748145fb22dcb52bb325a0c.jpg', json_data)

# %%
model = hourglass.network()

# %%
TRAIN_XPATH = r'Aquarium\train'

# %%
train_datagen = datagen.DataFlow(TRAIN_XPATH, True)
train_data = datagen.DataGen(train_datagen, 50)

# %%
model.compile(loss = losses.total_loss, optimizer = 'Adam')
# model.fit(train_data, epochs = 1)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │     18,944 │ input_layer[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │    295,168 │ conv2d[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
